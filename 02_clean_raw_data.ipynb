# %%
import glob
from PyPDF2 import PdfReader
import pandas as pd
import numpy as np
import docx
from striprtf.striprtf import rtf_to_text
import sys
import os
from bs4 import BeautifulSoup
import comtypes.client #throwing error
import shutil
import win32com.client
import pytesseract
from PIL import Image
from docx.api import Document
import time
import regex as re
max_rec = 0x100000
sys.setrecursionlimit(max_rec)
pytesseract.pytesseract.tesseract_cmd = "C:\\Users\\HaoLuo\\AppData\\Local\\Programs\\Tesseract-OCR\\tesseract.exe"
st = time.time()

# %%
def scrape_html(soup):
  '''retrieve relevant content from b4s'''

  #init empty dict
  html_dict = dict()

  #put all 'b' tags into dictionary to capture meta data
  for tag in soup.find_all(name='b'):
    html_dict[tag.contents[0].split(':')[0]] = tag.next_sibling.string

  #comment is two siblings behind heading
    if soup.find(name='h2',string="General Comment") is not None:
        html_dict["Comment"] = soup.find(name='h2',string="General Comment").next_sibling.next_sibling.text
    elif soup.find(name='h2',string="Redacted Comment") is not None:
        html_dict["Comment"] = soup.find(name='h2',string="Redacted Comment").next_sibling.next_sibling.text
        
  #We only care if attachment exists. Attachment must be grabbed using the comment name, not the attachment name
  if soup.find(name='h2',string="Attachments"):
    html_dict["has_attachments"] = True
  else:
    html_dict["has_attachments"] = False

  return html_dict

def scrape_pdf(file_name):
  ''' scrape pdf '''

  reader = PdfReader(file_name)
  text = ""
  for page in reader.pages:
      text += page.extract_text() + "\n"

  return text

def scrape_rtf(filename):
    with open(filename) as infile:
        content = infile.read()
        text = rtf_to_text(content)
    return text

def scrape_txt(filename):
    with open(filename) as infile:
        text = infile.read()
    return text

def scrape_docx(file_name):
    doc = docx.Document(file_name)
 
    #pull in pararaphs
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
 
    joinedText = '\n'.join(fullText)
 
    if len(doc.tables)>0:
      #pull in tables afterwards
      fullTable = ""
      for table in doc.tables:
          for row in table.rows:
              row_data = [cell.text for cell in row.cells]
              fullTable += ", ".join(row_data) + "\n"
      return (joinedText + '\n ' + fullTable, True)
    else:
      return (joinedText, False)

def scrape_xlsx(file_name):
  #pulls in a dictionary object of all tabs
  all_tabs_dict = pd.read_excel(file_name, na_values='', sheet_name=None)
 
  fullText = ""
  for df in list(all_tabs_dict.values()):
    for i in range(df.shape[0]):
        row_data = [str(df.iloc[i,j]) for j in range(df.shape[1])]
        fullText += ", ".join(row_data) + "\n"
 
  #remove multiple commas resulting from blank cells      
  fullText = re.sub(r',{2,}', ',', fullText)
  return fullText

def scrape_png(file_name):
    text = str(pytesseract.image_to_string(Image.open(file_name)))
    return text

# %%
def get_dataframe():    
    path ='C:/Users/HaoLuo/ACF-2023-0011/ACF-2023-0011' # set your own path
    files = os.listdir(path)
    os.chdir(path)
    set([x.split('.')[-1] for x in files])

    files_html = [x for x in files if x.endswith('.html') and x.startswith("ACF-")]
    html_dict_list=[]
    for file_path in files_html:
      #load html
      with open(path+"/"+file_path, 'r') as file:
        html_string=file.read()
        soup = BeautifulSoup(html_string, 'html.parser')
        print(file_path)
      #clean if public submission
      if soup.find_all(name='h1')[0].contents == ["PUBLIC SUBMISSION"]:
        html_dict = scrape_html(soup)

        #pull file paths for matching attachments
        attachment_paths = [x for x in files if html_dict['Document'] in x and not x.endswith(".html")]
        attachment_found = False
        html_dict["attachment_count"]=len(attachment_paths) #new line

        for attachment_path in attachment_paths:
            html_dict["attachment_name"] = attachment_path
            if attachment_path.endswith('.pdf'):
                html_dict["attachment_text"] = scrape_pdf(path+"/"+attachment_path)
                html_dict_list.append(html_dict.copy())
                attachment_found = True
            elif attachment_path.endswith('.docx'):
                html_dict["attachment_text"], html_dict["attachment_has_tables"] = scrape_docx(path+"/"+attachment_path) # new line
                html_dict["attachment_error"] = (len("attachment_text")==0)
                html_dict_list.append(html_dict.copy())
                attachment_found = True
            elif attachment_path.endswith('.rtf'):
                html_dict["attachment_text"] = scrape_rtf(path+"/"+attachment_path)
                html_dict_list.append(html_dict.copy())
                attachment_found = True
            elif attachment_path.endswith('.txt'):
                html_dict["attachment_text"] = scrape_txt(path+"/"+attachment_path)
                html_dict_list.append(html_dict.copy())
                attachment_found = True
            elif attachment_path.endswith('.png'):
                html_dict["attachment_text"] = scrape_png(path+"/"+attachment_path)
                html_dict_list.append(html_dict.copy())
                attachment_found = True
            elif attachment_path.endswith('.xlsx'):
                html_dict["attachment_text"] = scrape_xlsx(path+"/"+attachment_path)
                html_dict_list.append(html_dict.copy())
                attachment_found = True

        if attachment_found == False:
          #add row without attachment text
          html_dict_list.append(html_dict)

    df=pd.DataFrame(html_dict_list)
    
    for col_name in ["Comment","attachment_text"]:
      col_name_new = col_name+"_clean"

      #text cleaning
      df[col_name_new] = df[col_name].replace(to_replace=float('nan'),value='')

      df[col_name_new] = df[col_name_new].replace(to_replace='\xa0',value='')
      df[col_name_new] = df[col_name_new].str.replace(pat='§§',repl='bill number ')
      df[col_name_new] = df[col_name_new].str.replace(pat='§',repl='bill number ')
      df[col_name_new] = df[col_name_new].str.replace(pat='\u2009',repl='')

      df[col_name_new] = df[col_name_new].apply(lambda x: x.strip())
      df[col_name_new] = df[col_name_new].apply(lambda x: re.sub(r' +', ' ', x))
      df[col_name_new] = df[col_name_new].apply(lambda x: re.sub(r'\n +', '\n', x))
      df[col_name_new] = df[col_name_new].apply(lambda x: re.sub(r'\n+', '\n', x))
    return df

# %%
dff = get_dataframe()
congress = pd.read_excel("2024_jan_congress_members.xlsx")
congress_names = congress.Name.to_list()
 
dff["head_start_commenter"] = dff.Organization.str.contains(pat=r"Head Start.*?Association",case=False)
dff["congress_commenter"] = dff["Name"].apply(lambda x: x in congress_names)
dff.head()
# Out:
# ACF-2023-0011-0002.html
# ACF-2023-0011-0003.html
# ACF-2023-0011-0004.html
# ACF-2023-0011-0005.html
# ACF-2023-0011-0006.html
# ACF-2023-0011-0007.html
# ACF-2023-0011-0008.html
# ACF-2023-0011-0009.html
# ACF-2023-0011-0010.html
# ACF-2023-0011-0011.html
# ACF-2023-0011-0012.html
# ACF-2023-0011-0013.html
# ACF-2023-0011-0014.html
# ACF-2023-0011-0015.html
# ACF-2023-0011-0016.html
# ACF-2023-0011-0017.html
# ACF-2023-0011-0018.html
# ACF-2023-0011-0019.html
# ACF-2023-0011-0020.html
# ACF-2023-0011-0021.html
# ACF-2023-0011-0022.html
# ACF-2023-0011-0023.html
# ACF-2023-0011-0024.html
# ACF-2023-0011-0025.html
# ACF-2023-0011-0026.html
# ACF-2023-0011-0027.html
# ACF-2023-0011-0028.html
# ACF-2023-0011-0029.html
# ACF-2023-0011-0030.html
# ACF-2023-0011-0031.html
# ACF-2023-0011-0032.html
# ACF-2023-0011-0033.html
# ACF-2023-0011-0034.html
# ACF-2023-0011-0035.html
# ACF-2023-0011-0036.html
# ACF-2023-0011-0037.html
# ACF-2023-0011-0038.html
# ACF-2023-0011-0039.html
# ACF-2023-0011-0040.html
# ACF-2023-0011-0041.html
# ACF-2023-0011-0042.html
# ACF-2023-0011-0043.html
# ACF-2023-0011-0044.html
# ACF-2023-0011-0045.html
# ACF-2023-0011-0046.html
# ACF-2023-0011-0047.html
# ACF-2023-0011-0048.html
# ACF-2023-0011-0049.html
# ACF-2023-0011-0050.html
# ACF-2023-0011-0051.html
# ACF-2023-0011-0052.html
# ACF-2023-0011-0053.html
# ACF-2023-0011-0054.html
# ACF-2023-0011-0055.html
# ACF-2023-0011-0056.html
# ACF-2023-0011-0057.html
# ACF-2023-0011-0058.html
# ACF-2023-0011-0059.html
# ACF-2023-0011-0060.html
# ACF-2023-0011-0061.html
# ACF-2023-0011-0062.html
# ACF-2023-0011-0063.html
# ACF-2023-0011-0064.html
# ACF-2023-0011-0065.html
# ACF-2023-0011-0066.html
# ACF-2023-0011-0067.html
# ACF-2023-0011-0068.html
# ACF-2023-0011-0069.html
# ACF-2023-0011-0070.html
# ACF-2023-0011-0071.html
# ACF-2023-0011-0072.html
# ACF-2023-0011-0073.html
# ACF-2023-0011-0074.html
# ACF-2023-0011-0075.html
# ACF-2023-0011-0076.html
# ACF-2023-0011-0077.html
# ACF-2023-0011-0078.html
# ACF-2023-0011-0079.html
# ACF-2023-0011-0080.html
# ACF-2023-0011-0081.html
# ACF-2023-0011-0082.html
# ACF-2023-0011-0083.html
# ACF-2023-0011-0084.html
# ACF-2023-0011-0085.html
# ACF-2023-0011-0086.html
# ACF-2023-0011-0087.html
# ACF-2023-0011-0088.html
# ACF-2023-0011-0089.html
# ACF-2023-0011-0090.html
# ACF-2023-0011-0091.html
# ACF-2023-0011-0092.html
# ACF-2023-0011-0093.html
# ACF-2023-0011-0094.html
# ACF-2023-0011-0095.html
# ACF-2023-0011-0096.html
# ACF-2023-0011-0097.html
# ACF-2023-0011-0098.html
# ACF-2023-0011-0099.html
# ACF-2023-0011-0100.html
# ACF-2023-0011-0101.html
# ACF-2023-0011-0102.html
# ACF-2023-0011-0103.html
# ACF-2023-0011-0104.html
# ACF-2023-0011-0105.html
# ACF-2023-0011-0106.html
# ACF-2023-0011-0107.html
# ACF-2023-0011-0108.html
# ACF-2023-0011-0109.html
# ACF-2023-0011-0110.html
# ACF-2023-0011-0111.html
# ACF-2023-0011-0112.html
# ACF-2023-0011-0113.html
# ACF-2023-0011-0114.html
# ACF-2023-0011-0115.html
# ACF-2023-0011-0116.html
# ACF-2023-0011-0117.html
# ACF-2023-0011-0118.html
# ACF-2023-0011-0119.html
# ACF-2023-0011-0120.html
# ACF-2023-0011-0121.html
# ACF-2023-0011-0122.html
# ACF-2023-0011-0123.html
# ACF-2023-0011-0124.html
# ACF-2023-0011-0125.html
# ACF-2023-0011-0126.html
# ACF-2023-0011-0127.html
# ACF-2023-0011-0128.html
# ACF-2023-0011-0129.html
# ACF-2023-0011-0130.html
# ACF-2023-0011-0131.html
# ACF-2023-0011-0132.html
# ACF-2023-0011-0133.html
# ACF-2023-0011-0134.html
# ACF-2023-0011-0135.html
# ACF-2023-0011-0136.html
# ACF-2023-0011-0137.html
# ACF-2023-0011-0138.html
# ACF-2023-0011-0139.html
# ACF-2023-0011-0140.html
# ACF-2023-0011-0141.html
# ACF-2023-0011-0142.html
# ACF-2023-0011-0143.html
# ACF-2023-0011-0144.html
# ACF-2023-0011-0145.html
# ACF-2023-0011-0146.html
# ACF-2023-0011-0147.html
# ACF-2023-0011-0148.html
# ACF-2023-0011-0149.html
# ACF-2023-0011-0150.html
# ACF-2023-0011-0151.html
# ACF-2023-0011-0152.html
# ACF-2023-0011-0153.html
# ACF-2023-0011-0154.html
# ACF-2023-0011-0155.html
# ACF-2023-0011-0156.html
# ACF-2023-0011-0157.html
# ACF-2023-0011-0158.html
# ACF-2023-0011-0159.html
# ACF-2023-0011-0160.html
# ACF-2023-0011-0161.html
# ACF-2023-0011-0162.html
# ACF-2023-0011-0163.html
# ACF-2023-0011-0164.html
# ACF-2023-0011-0165.html
# ACF-2023-0011-0166.html
# ACF-2023-0011-0167.html
# ACF-2023-0011-0168.html
# ACF-2023-0011-0169.html
# ACF-2023-0011-0170.html
# ACF-2023-0011-0171.html
# ACF-2023-0011-0172.html
# ACF-2023-0011-0173.html
# ACF-2023-0011-0174.html
# ACF-2023-0011-0175.html
# ACF-2023-0011-0176.html
# ACF-2023-0011-0177.html
# ACF-2023-0011-0178.html
# ACF-2023-0011-0179.html
# ACF-2023-0011-0180.html
# ACF-2023-0011-0181.html
# ACF-2023-0011-0182.html
# ACF-2023-0011-0183.html
# ACF-2023-0011-0184.html
# ACF-2023-0011-0185.html
# ACF-2023-0011-0186.html
# ACF-2023-0011-0187.html
# ACF-2023-0011-0188.html
# ACF-2023-0011-0189.html
# ACF-2023-0011-0190.html
# ACF-2023-0011-0191.html
# ACF-2023-0011-0192.html
# ACF-2023-0011-0193.html
# ACF-2023-0011-0194.html
# ACF-2023-0011-0195.html
# ACF-2023-0011-0196.html
# ACF-2023-0011-0197.html
# ACF-2023-0011-0198.html
# ACF-2023-0011-0199.html
# ACF-2023-0011-0200.html
# ACF-2023-0011-0201.html
# ACF-2023-0011-0202.html
# ACF-2023-0011-0203.html
# ACF-2023-0011-0204.html
# ACF-2023-0011-0205.html
# ACF-2023-0011-0206.html
# ACF-2023-0011-0207.html
# ACF-2023-0011-0208.html
# ACF-2023-0011-0209.html
# ACF-2023-0011-0210.html
# ACF-2023-0011-0211.html
# ACF-2023-0011-0212.html
# ACF-2023-0011-0213.html
# ACF-2023-0011-0214.html
# ACF-2023-0011-0215.html
# ACF-2023-0011-0216.html
# ACF-2023-0011-0217.html
# ACF-2023-0011-0218.html
# ACF-2023-0011-0219.html
# ACF-2023-0011-0220.html
# ACF-2023-0011-0221.html
# ACF-2023-0011-0222.html
# ACF-2023-0011-0223.html
# ACF-2023-0011-0224.html
# ACF-2023-0011-0225.html
# ACF-2023-0011-0226.html
# ACF-2023-0011-0227.html
# ACF-2023-0011-0228.html
# ACF-2023-0011-0229.html
# ACF-2023-0011-0230.html
# ACF-2023-0011-0231.html
# ACF-2023-0011-0232.html
# ACF-2023-0011-0233.html
# ACF-2023-0011-0234.html
# ACF-2023-0011-0235.html
# ACF-2023-0011-0236.html
# ACF-2023-0011-0237.html
# ACF-2023-0011-0238.html
# ACF-2023-0011-0239.html
# ACF-2023-0011-0240.html
# ACF-2023-0011-0241.html
# ACF-2023-0011-0242.html
# ACF-2023-0011-0243.html
# ACF-2023-0011-0244.html
# ACF-2023-0011-0245.html
# ACF-2023-0011-0246.html
# ACF-2023-0011-0247.html
# ACF-2023-0011-0248.html
# ACF-2023-0011-0249.html
# ACF-2023-0011-0250.html
# ACF-2023-0011-0251.html
# ACF-2023-0011-0252.html
# ACF-2023-0011-0253.html
# ACF-2023-0011-0254.html
# ACF-2023-0011-0255.html
# ACF-2023-0011-0256.html
# ACF-2023-0011-0257.html
# ACF-2023-0011-0258.html
# ACF-2023-0011-0259.html
# ACF-2023-0011-0260.html
# ACF-2023-0011-0261.html
# ACF-2023-0011-0262.html
# ACF-2023-0011-0263.html
# ACF-2023-0011-0264.html
# ACF-2023-0011-0265.html
# ACF-2023-0011-0266.html
# ACF-2023-0011-0267.html
# ACF-2023-0011-0268.html
# ACF-2023-0011-0269.html
# ACF-2023-0011-0270.html
# ACF-2023-0011-0271.html
# ACF-2023-0011-0272.html
# ACF-2023-0011-0273.html
# ACF-2023-0011-0274.html
# ACF-2023-0011-0275.html
# ACF-2023-0011-0276.html
# ACF-2023-0011-0277.html
# ACF-2023-0011-0278.html
# ACF-2023-0011-0279.html
# ACF-2023-0011-0280.html
# ACF-2023-0011-0281.html
# ACF-2023-0011-0282.html
# ACF-2023-0011-0283.html
# ACF-2023-0011-0284.html
# ACF-2023-0011-0285.html
# ACF-2023-0011-0286.html
# ACF-2023-0011-0287.html
# ACF-2023-0011-0288.html
# ACF-2023-0011-0289.html
# ACF-2023-0011-0290.html
# ACF-2023-0011-0291.html
# ACF-2023-0011-0292.html
# ACF-2023-0011-0293.html
# ACF-2023-0011-0294.html
# ACF-2023-0011-0295.html
# ACF-2023-0011-0296.html
# ACF-2023-0011-0297.html
# ACF-2023-0011-0298.html
# ACF-2023-0011-0299.html
# ACF-2023-0011-0300.html
# ACF-2023-0011-0301.html
# ACF-2023-0011-0302.html
# ACF-2023-0011-0303.html
# ACF-2023-0011-0304.html
# ACF-2023-0011-0305.html
# ACF-2023-0011-0306.html
# ACF-2023-0011-0307.html
# ACF-2023-0011-0308.html
# ACF-2023-0011-0309.html
# ACF-2023-0011-0310.html
# ACF-2023-0011-0311.html
# ACF-2023-0011-0312.html
# ACF-2023-0011-0313.html
# ACF-2023-0011-0314.html
# ACF-2023-0011-0315.html
# ACF-2023-0011-0316.html
# ACF-2023-0011-0317.html
# ACF-2023-0011-0318.html
# ACF-2023-0011-0319.html
# ACF-2023-0011-0320.html
# ACF-2023-0011-0321.html
# ACF-2023-0011-0322.html
# ACF-2023-0011-0323.html
# ACF-2023-0011-0324.html
# ACF-2023-0011-0325.html
# ACF-2023-0011-0326.html
# ACF-2023-0011-0327.html
# ACF-2023-0011-0328.html
# ACF-2023-0011-0329.html
# ACF-2023-0011-0330.html
# ACF-2023-0011-0331.html
# ACF-2023-0011-0332.html
# ACF-2023-0011-0333.html
# ACF-2023-0011-0334.html
# ACF-2023-0011-0335.html
# ACF-2023-0011-0336.html
# ACF-2023-0011-0337.html
# ACF-2023-0011-0338.html
# ACF-2023-0011-0339.html
# ACF-2023-0011-0340.html
# ACF-2023-0011-0341.html
# ACF-2023-0011-0342.html
# ACF-2023-0011-0343.html
# ACF-2023-0011-0344.html
# ACF-2023-0011-0345.html
# ACF-2023-0011-0346.html
# ACF-2023-0011-0347.html
# ACF-2023-0011-0348.html
# ACF-2023-0011-0349.html
# ACF-2023-0011-0350.html
# ACF-2023-0011-0351.html
# ACF-2023-0011-0352.html
# ACF-2023-0011-0353.html
# ACF-2023-0011-0354.html
# ACF-2023-0011-0355.html
# ACF-2023-0011-0356.html
# ACF-2023-0011-0357.html
# ACF-2023-0011-0358.html
# ACF-2023-0011-0359.html
# ACF-2023-0011-0360.html
# ACF-2023-0011-0361.html
# ACF-2023-0011-0362.html
# ACF-2023-0011-0363.html
# ACF-2023-0011-0364.html
# ACF-2023-0011-0365.html
# ACF-2023-0011-0366.html
# ACF-2023-0011-0367.html
# ACF-2023-0011-0368.html
# ACF-2023-0011-0369.html
# ACF-2023-0011-0370.html
# ACF-2023-0011-0371.html
# ACF-2023-0011-0372.html
# ACF-2023-0011-0373.html
# ACF-2023-0011-0374.html
# ACF-2023-0011-0375.html
# ACF-2023-0011-0376.html
# ACF-2023-0011-0377.html
# ACF-2023-0011-0378.html
# ACF-2023-0011-0379.html
# ACF-2023-0011-0380.html
# ACF-2023-0011-0381.html
# ACF-2023-0011-0382.html
# ACF-2023-0011-0383.html
# ACF-2023-0011-0384.html
# ACF-2023-0011-0385.html
# ACF-2023-0011-0386.html
# ACF-2023-0011-0387.html
# ACF-2023-0011-0388.html
# ACF-2023-0011-0389.html
# ACF-2023-0011-0390.html
# ACF-2023-0011-0391.html
# ACF-2023-0011-0392.html
# ACF-2023-0011-0393.html
# ACF-2023-0011-0394.html
# ACF-2023-0011-0395.html
# ACF-2023-0011-0396.html
# ACF-2023-0011-0397.html
# ACF-2023-0011-0398.html
# ACF-2023-0011-0399.html
# ACF-2023-0011-0400.html
# ACF-2023-0011-0401.html
# ACF-2023-0011-0402.html
# ACF-2023-0011-0403.html
# ACF-2023-0011-0404.html
# ACF-2023-0011-0405.html
# ACF-2023-0011-0406.html
# ACF-2023-0011-0407.html
# ACF-2023-0011-0408.html
# ACF-2023-0011-0409.html
# ACF-2023-0011-0410.html
# ACF-2023-0011-0411.html
# ACF-2023-0011-0412.html
# ACF-2023-0011-0413.html
# ACF-2023-0011-0414.html
# ACF-2023-0011-0415.html
# ACF-2023-0011-0416.html
# ACF-2023-0011-0417.html
# ACF-2023-0011-0418.html
# ACF-2023-0011-0419.html
# ACF-2023-0011-0420.html
# ACF-2023-0011-0421.html
# ACF-2023-0011-0422.html
# ACF-2023-0011-0423.html
# ACF-2023-0011-0424.html
# ACF-2023-0011-0425.html
# ACF-2023-0011-0426.html
# ACF-2023-0011-0427.html
# ACF-2023-0011-0428.html
# ACF-2023-0011-0429.html
# ACF-2023-0011-0430.html
# ACF-2023-0011-0431.html
# ACF-2023-0011-0432.html
# ACF-2023-0011-0433.html
# ACF-2023-0011-0434.html
# ACF-2023-0011-0435.html
# ACF-2023-0011-0436.html
# ACF-2023-0011-0437.html
# ACF-2023-0011-0438.html
# ACF-2023-0011-0439.html
# ACF-2023-0011-0440.html
# ACF-2023-0011-0441.html
# ACF-2023-0011-0442.html
# ACF-2023-0011-0443.html
# ACF-2023-0011-0444.html
# ACF-2023-0011-0445.html
# ACF-2023-0011-0446.html
# ACF-2023-0011-0447.html
# ACF-2023-0011-0448.html
# ACF-2023-0011-0449.html
# ACF-2023-0011-0450.html
# ACF-2023-0011-0451.html
# ACF-2023-0011-0452.html
# ACF-2023-0011-0453.html
# ACF-2023-0011-0454.html
# ACF-2023-0011-0455.html
# ACF-2023-0011-0456.html
# ACF-2023-0011-0457.html
# ACF-2023-0011-0458.html
# ACF-2023-0011-0459.html
# ACF-2023-0011-0460.html
# ACF-2023-0011-0461.html
# ACF-2023-0011-0462.html
# ACF-2023-0011-0463.html
# ACF-2023-0011-0464.html
# ACF-2023-0011-0465.html
# ACF-2023-0011-0466.html
# ACF-2023-0011-0467.html
# ACF-2023-0011-0468.html
# ACF-2023-0011-0469.html
# ACF-2023-0011-0470.html
# ACF-2023-0011-0471.html
# ACF-2023-0011-0472.html
# ACF-2023-0011-0473.html
# ACF-2023-0011-0474.html
# ACF-2023-0011-0475.html
# ACF-2023-0011-0476.html
# ACF-2023-0011-0477.html
# ACF-2023-0011-0478.html
# ACF-2023-0011-0479.html
# ACF-2023-0011-0480.html
# ACF-2023-0011-0481.html
# ACF-2023-0011-0482.html
# ACF-2023-0011-0483.html
# ACF-2023-0011-0484.html
# ACF-2023-0011-0485.html
# ACF-2023-0011-0486.html
# ACF-2023-0011-0487.html
# ACF-2023-0011-0488.html
# ACF-2023-0011-0489.html
# ACF-2023-0011-0490.html
# ACF-2023-0011-0491.html
# ACF-2023-0011-0492.html
# ACF-2023-0011-0493.html
# ACF-2023-0011-0494.html
# ACF-2023-0011-0495.html
# ACF-2023-0011-0496.html
# ACF-2023-0011-0497.html
# ACF-2023-0011-0498.html
# ACF-2023-0011-0499.html
# ACF-2023-0011-0500.html
# ACF-2023-0011-0501.html
# ACF-2023-0011-0502.html
# ACF-2023-0011-0503.html
# ACF-2023-0011-0504.html
# ACF-2023-0011-0505.html
# ACF-2023-0011-0506.html
# ACF-2023-0011-0507.html
# ACF-2023-0011-0508.html
# ACF-2023-0011-0509.html
# ACF-2023-0011-0510.html
# ACF-2023-0011-0511.html
# ACF-2023-0011-0512.html
# ACF-2023-0011-0513.html
# ACF-2023-0011-0514.html
# ACF-2023-0011-0515.html
# ACF-2023-0011-0516.html
# ACF-2023-0011-0517.html
# ACF-2023-0011-0518.html
# ACF-2023-0011-0519.html
# ACF-2023-0011-0520.html
# ACF-2023-0011-0521.html
# ACF-2023-0011-0522.html
# ACF-2023-0011-0523.html
# ACF-2023-0011-0524.html
# ACF-2023-0011-0525.html
# ACF-2023-0011-0526.html
# ACF-2023-0011-0527.html
# ACF-2023-0011-0528.html
# ACF-2023-0011-0529.html
# ACF-2023-0011-0530.html
# ACF-2023-0011-0531.html
# ACF-2023-0011-0532.html
# ACF-2023-0011-0533.html
# ACF-2023-0011-0534.html
# ACF-2023-0011-0535.html
# ACF-2023-0011-0536.html
# ACF-2023-0011-0537.html
# ACF-2023-0011-0538.html
# ACF-2023-0011-0539.html
# ACF-2023-0011-0540.html
# ACF-2023-0011-0541.html
# ACF-2023-0011-0542.html
# ACF-2023-0011-0543.html
# ACF-2023-0011-0544.html
# ACF-2023-0011-0545.html
# ACF-2023-0011-0546.html
# ACF-2023-0011-0547.html
# ACF-2023-0011-0548.html
# ACF-2023-0011-0549.html
# ACF-2023-0011-0550.html
# ACF-2023-0011-0551.html
# ACF-2023-0011-0552.html
# ACF-2023-0011-0553.html
# ACF-2023-0011-0554.html
# ACF-2023-0011-0555.html
# ACF-2023-0011-0556.html
# ACF-2023-0011-0557.html
# ACF-2023-0011-0558.html
# ACF-2023-0011-0559.html
# ACF-2023-0011-0560.html
# ACF-2023-0011-0561.html
# ACF-2023-0011-0562.html
# ACF-2023-0011-0563.html
# ACF-2023-0011-0564.html
# ACF-2023-0011-0565.html
# ACF-2023-0011-0566.html
# ACF-2023-0011-0567.html
# ACF-2023-0011-0568.html
# ACF-2023-0011-0569.html
# ACF-2023-0011-0570.html
# ACF-2023-0011-0571.html
# ACF-2023-0011-0572.html
# ACF-2023-0011-0573.html
# ACF-2023-0011-0574.html
# ACF-2023-0011-0575.html
# ACF-2023-0011-0576.html
# ACF-2023-0011-0577.html
# ACF-2023-0011-0578.html
# ACF-2023-0011-0579.html
# ACF-2023-0011-0580.html
# ACF-2023-0011-0581.html
# ACF-2023-0011-0582.html
# ACF-2023-0011-0583.html
# ACF-2023-0011-0584.html
# ACF-2023-0011-0585.html
# ACF-2023-0011-0586.html
# ACF-2023-0011-0587.html
# ACF-2023-0011-0588.html
# ACF-2023-0011-0589.html
# ACF-2023-0011-0590.html
# ACF-2023-0011-0591.html
# ACF-2023-0011-0592.html
# ACF-2023-0011-0593.html
# ACF-2023-0011-0594.html
# ACF-2023-0011-0595.html
# ACF-2023-0011-0596.html
# ACF-2023-0011-0597.html
# ACF-2023-0011-0598.html
# ACF-2023-0011-0599.html
# ACF-2023-0011-0600.html
# ACF-2023-0011-0601.html
# ACF-2023-0011-0602.html
# ACF-2023-0011-0603.html
# ACF-2023-0011-0604.html
# ACF-2023-0011-0605.html
# ACF-2023-0011-0606.html
# ACF-2023-0011-0607.html
# ACF-2023-0011-0608.html
# ACF-2023-0011-0609.html
# ACF-2023-0011-0610.html
# ACF-2023-0011-0611.html
# ACF-2023-0011-0612.html
# ACF-2023-0011-0613.html
# ACF-2023-0011-0614.html
# ACF-2023-0011-0615.html
# ACF-2023-0011-0616.html
# ACF-2023-0011-0617.html
# ACF-2023-0011-0618.html
# ACF-2023-0011-0619.html
# ACF-2023-0011-0620.html
# ACF-2023-0011-0621.html
# ACF-2023-0011-0622.html
# ACF-2023-0011-0623.html
# ACF-2023-0011-0624.html
# ACF-2023-0011-0625.html
# ACF-2023-0011-0626.html
# ACF-2023-0011-0627.html
# ACF-2023-0011-0628.html
# ACF-2023-0011-0629.html
# ACF-2023-0011-0630.html
# ACF-2023-0011-0631.html
# ACF-2023-0011-0632.html
# ACF-2023-0011-0633.html
# ACF-2023-0011-0634.html
# ACF-2023-0011-0635.html
# ACF-2023-0011-0636.html
# ACF-2023-0011-0637.html
# ACF-2023-0011-0638.html
# ACF-2023-0011-0639.html
# ACF-2023-0011-0640.html
# ACF-2023-0011-0641.html
# ACF-2023-0011-0642.html
# ACF-2023-0011-0643.html
# ACF-2023-0011-0644.html
# ACF-2023-0011-0645.html
# ACF-2023-0011-0646.html
# ACF-2023-0011-0647.html
# ACF-2023-0011-0648.html
# ACF-2023-0011-0649.html
# ACF-2023-0011-0650.html
# ACF-2023-0011-0651.html
# ACF-2023-0011-0652.html
# ACF-2023-0011-0653.html
# ACF-2023-0011-0654.html
# ACF-2023-0011-0655.html
# ACF-2023-0011-0656.html
# ACF-2023-0011-0657.html
# ACF-2023-0011-0658.html
# ACF-2023-0011-0659.html
# ACF-2023-0011-0660.html
# ACF-2023-0011-0661.html
# ACF-2023-0011-0662.html
# ACF-2023-0011-0663.html
# ACF-2023-0011-0664.html
# ACF-2023-0011-0665.html
# ACF-2023-0011-0666.html
# ACF-2023-0011-0667.html
# ACF-2023-0011-0668.html
# ACF-2023-0011-0669.html
# ACF-2023-0011-0670.html
# ACF-2023-0011-0671.html
# ACF-2023-0011-0672.html
# ACF-2023-0011-0673.html
# ACF-2023-0011-0674.html
# ACF-2023-0011-0675.html
# ACF-2023-0011-0676.html
# ACF-2023-0011-0677.html
# ACF-2023-0011-0678.html
# ACF-2023-0011-0679.html
# ACF-2023-0011-0680.html
# ACF-2023-0011-0681.html
# ACF-2023-0011-0682.html
# ACF-2023-0011-0683.html
# ACF-2023-0011-0684.html
# ACF-2023-0011-0685.html
# ACF-2023-0011-0686.html
# ACF-2023-0011-0687.html
# ACF-2023-0011-0688.html
# ACF-2023-0011-0689.html
# ACF-2023-0011-0690.html
# ACF-2023-0011-0691.html
# ACF-2023-0011-0692.html
# ACF-2023-0011-0693.html
# ACF-2023-0011-0694.html
# ACF-2023-0011-0695.html
# ACF-2023-0011-0696.html
# ACF-2023-0011-0697.html
# ACF-2023-0011-0698.html
# ACF-2023-0011-0699.html
# ACF-2023-0011-0700.html
# ACF-2023-0011-0701.html
# ACF-2023-0011-0702.html
# ACF-2023-0011-0703.html
# ACF-2023-0011-0704.html
# ACF-2023-0011-0705.html
# ACF-2023-0011-0706.html
# ACF-2023-0011-0707.html
# ACF-2023-0011-0708.html
# ACF-2023-0011-0709.html
# ACF-2023-0011-0710.html
# ACF-2023-0011-0711.html
# ACF-2023-0011-0712.html
# ACF-2023-0011-0713.html
# ACF-2023-0011-0714.html
# ACF-2023-0011-0715.html
# ACF-2023-0011-0716.html
# ACF-2023-0011-0717.html
# ACF-2023-0011-0718.html
# ACF-2023-0011-0719.html
# ACF-2023-0011-0720.html
# ACF-2023-0011-0721.html
# ACF-2023-0011-0722.html
# ACF-2023-0011-0723.html
# ACF-2023-0011-0724.html
# ACF-2023-0011-0725.html
# ACF-2023-0011-0726.html
# ACF-2023-0011-0727.html
# ACF-2023-0011-0728.html
# ACF-2023-0011-0729.html
# ACF-2023-0011-0730.html
# ACF-2023-0011-0731.html
# ACF-2023-0011-0732.html
# ACF-2023-0011-0733.html
# ACF-2023-0011-0734.html
# ACF-2023-0011-0735.html
# ACF-2023-0011-0736.html
# ACF-2023-0011-0737.html
# ACF-2023-0011-0738.html
# ACF-2023-0011-0739.html
# ACF-2023-0011-0740.html
# ACF-2023-0011-0741.html
# ACF-2023-0011-0742.html
# ACF-2023-0011-0743.html
# ACF-2023-0011-0744.html
# ACF-2023-0011-0745.html
# ACF-2023-0011-0746.html
# ACF-2023-0011-0747.html
# ACF-2023-0011-0748.html
# ACF-2023-0011-0749.html
# ACF-2023-0011-0750.html
# ACF-2023-0011-0751.html
# ACF-2023-0011-0752.html
# ACF-2023-0011-0753.html
# ACF-2023-0011-0754.html
# ACF-2023-0011-0755.html
# ACF-2023-0011-0756.html
# ACF-2023-0011-0757.html
# ACF-2023-0011-0758.html
# ACF-2023-0011-0759.html
# ACF-2023-0011-0760.html
# ACF-2023-0011-0761.html
# ACF-2023-0011-0762.html
# ACF-2023-0011-0763.html
# ACF-2023-0011-0764.html
# ACF-2023-0011-0765.html
# ACF-2023-0011-0766.html
# ACF-2023-0011-0767.html
# ACF-2023-0011-0768.html
# ACF-2023-0011-0769.html
# ACF-2023-0011-0770.html
# ACF-2023-0011-0771.html
# ACF-2023-0011-0772.html
# ACF-2023-0011-0773.html
# ACF-2023-0011-0774.html
# ACF-2023-0011-0775.html
# ACF-2023-0011-0776.html
# ACF-2023-0011-0777.html
# ACF-2023-0011-0778.html
# ACF-2023-0011-0779.html
# ACF-2023-0011-0780.html
# ACF-2023-0011-0781.html
# ACF-2023-0011-0782.html
# ACF-2023-0011-0783.html
# ACF-2023-0011-0784.html
# ACF-2023-0011-0785.html
# ACF-2023-0011-0786.html
# ACF-2023-0011-0787.html
# ACF-2023-0011-0788.html
# ACF-2023-0011-0789.html
# ACF-2023-0011-0790.html
# ACF-2023-0011-0791.html
# ACF-2023-0011-0792.html
# ACF-2023-0011-0793.html
# ACF-2023-0011-0794.html
# ACF-2023-0011-0795.html
# ACF-2023-0011-0796.html
# ACF-2023-0011-0797.html
# ACF-2023-0011-0798.html
# ACF-2023-0011-0799.html
# ACF-2023-0011-0800.html
# ACF-2023-0011-0801.html
# ACF-2023-0011-0802.html
# ACF-2023-0011-0803.html
# ACF-2023-0011-0804.html
# ACF-2023-0011-0805.html
# ACF-2023-0011-0806.html
# ACF-2023-0011-0807.html
# ACF-2023-0011-0808.html
# ACF-2023-0011-0809.html
# ACF-2023-0011-0810.html
# ACF-2023-0011-0811.html
# ACF-2023-0011-0812.html
# ACF-2023-0011-0813.html
# ACF-2023-0011-0814.html
# ACF-2023-0011-0815.html
# ACF-2023-0011-0816.html
# ACF-2023-0011-0817.html
# ACF-2023-0011-0818.html
# ACF-2023-0011-0819.html
# ACF-2023-0011-0820.html
# ACF-2023-0011-0821.html
# ACF-2023-0011-0822.html
# ACF-2023-0011-0823.html
# ACF-2023-0011-0824.html
# ACF-2023-0011-0825.html
# ACF-2023-0011-0826.html
# ACF-2023-0011-0827.html
# ACF-2023-0011-0828.html
# ACF-2023-0011-0829.html
# ACF-2023-0011-0830.html
# ACF-2023-0011-0831.html
# ACF-2023-0011-0832.html
# ACF-2023-0011-0833.html
# ACF-2023-0011-0834.html
# ACF-2023-0011-0835.html
# ACF-2023-0011-0836.html
# ACF-2023-0011-0837.html
# ACF-2023-0011-0838.html
# ACF-2023-0011-0839.html
# ACF-2023-0011-0840.html
# ACF-2023-0011-0841.html
# ACF-2023-0011-0842.html
# ACF-2023-0011-0843.html
# ACF-2023-0011-0844.html
# ACF-2023-0011-0845.html
# ACF-2023-0011-0846.html
# ACF-2023-0011-0847.html
# ACF-2023-0011-0848.html
# ACF-2023-0011-0849.html
# ACF-2023-0011-0850.html
# ACF-2023-0011-0851.html
# ACF-2023-0011-0852.html
# ACF-2023-0011-0853.html
# ACF-2023-0011-0854.html
# ACF-2023-0011-0855.html
# ACF-2023-0011-0856.html
# ACF-2023-0011-0857.html
# ACF-2023-0011-0858.html
# ACF-2023-0011-0859.html
# ACF-2023-0011-0860.html
# ACF-2023-0011-0861.html
# ACF-2023-0011-0862.html
# ACF-2023-0011-0863.html
# ACF-2023-0011-0864.html
# ACF-2023-0011-0865.html
# ACF-2023-0011-0866.html
# ACF-2023-0011-0867.html
# ACF-2023-0011-0868.html
# ACF-2023-0011-0869.html
# ACF-2023-0011-0870.html
# ACF-2023-0011-0871.html
# ACF-2023-0011-0872.html
# ACF-2023-0011-0873.html
# ACF-2023-0011-0874.html
# ACF-2023-0011-0875.html
# ACF-2023-0011-0876.html
# ACF-2023-0011-0877.html
# ACF-2023-0011-0878.html
# ACF-2023-0011-0879.html
# ACF-2023-0011-0880.html
# ACF-2023-0011-0881.html
# ACF-2023-0011-0882.html
# ACF-2023-0011-0883.html
# ACF-2023-0011-0884.html
# ACF-2023-0011-0885.html
# ACF-2023-0011-0886.html
# ACF-2023-0011-0887.html
# ACF-2023-0011-0888.html
# ACF-2023-0011-0889.html
# ACF-2023-0011-0890.html
# ACF-2023-0011-0891.html
# ACF-2023-0011-0892.html
# ACF-2023-0011-0893.html
# ACF-2023-0011-0894.html
# ACF-2023-0011-0895.html
# ACF-2023-0011-0896.html
# ACF-2023-0011-0897.html
# ACF-2023-0011-0898.html
# ACF-2023-0011-0899.html
# ACF-2023-0011-0900.html
# ACF-2023-0011-0901.html
# ACF-2023-0011-0902.html
# ACF-2023-0011-0903.html
# ACF-2023-0011-0904.html
# ACF-2023-0011-0905.html
# ACF-2023-0011-0906.html
# ACF-2023-0011-0907.html
# ACF-2023-0011-0908.html
# ACF-2023-0011-0909.html
# ACF-2023-0011-0910.html
# ACF-2023-0011-0911.html
# ACF-2023-0011-0912.html
# ACF-2023-0011-0913.html
# ACF-2023-0011-0914.html
# ACF-2023-0011-0915.html
# ACF-2023-0011-0916.html
# ACF-2023-0011-0917.html
# ACF-2023-0011-0918.html
# ACF-2023-0011-0919.html
# ACF-2023-0011-0920.html
# ACF-2023-0011-0921.html
# ACF-2023-0011-0922.html
# ACF-2023-0011-0923.html
# ACF-2023-0011-0924.html
# ACF-2023-0011-0925.html
# ACF-2023-0011-0926.html
# ACF-2023-0011-0927.html
# ACF-2023-0011-0928.html
# ACF-2023-0011-0929.html
# ACF-2023-0011-0930.html
# ACF-2023-0011-0931.html
# ACF-2023-0011-0932.html
# ACF-2023-0011-0933.html
# ACF-2023-0011-0934.html
# ACF-2023-0011-0935.html
# ACF-2023-0011-0936.html
# ACF-2023-0011-0937.html
# ACF-2023-0011-0938.html
# ACF-2023-0011-0939.html
# ACF-2023-0011-0940.html
# ACF-2023-0011-0941.html
# ACF-2023-0011-0942.html
# ACF-2023-0011-0943.html
# ACF-2023-0011-0944.html
# ACF-2023-0011-0945.html
# ACF-2023-0011-0946.html
# ACF-2023-0011-0947.html
# ACF-2023-0011-0948.html
# ACF-2023-0011-0949.html
# ACF-2023-0011-0950.html
# ACF-2023-0011-DRAFT-0101.html
# ACF-2023-0011-DRAFT-0119.html
# ACF-2023-0011-DRAFT-0124.html
# ACF-2023-0011-DRAFT-0953.html
# ACF-2023-0011-DRAFT-0954.html
# ACF-2023-0011-DRAFT-0955.html
# ACF-2023-0011-DRAFT-0956.html
# ACF-2023-0011-DRAFT-0957.html
# ACF-2023-0011-DRAFT-0958.html
# ACF-2023-0011-DRAFT-0959.html
# ACF-2023-0011-DRAFT-0960.html
# ACF-2023-0011-DRAFT-0961.html
# ACF-2023-0011-DRAFT-0962.html
# ACF-2023-0011-DRAFT-0963.html
# ACF-2023-0011-DRAFT-0964.html
# ACF-2023-0011-DRAFT-0965.html
# ACF-2023-0011-DRAFT-0966.html
# ACF-2023-0011-DRAFT-0967.html
# ACF-2023-0011-DRAFT-0968.html
# ACF-2023-0011-DRAFT-0969.html
# ACF-2023-0011-DRAFT-0970.html
# ACF-2023-0011-DRAFT-0971.html
# ACF-2023-0011-DRAFT-0972.html
# ACF-2023-0011-DRAFT-0973.html
# ACF-2023-0011-DRAFT-0974.html
# ACF-2023-0011-DRAFT-0975.html
# ACF-2023-0011-DRAFT-0976.html
# ACF-2023-0011-DRAFT-0977.html
# ACF-2023-0011-DRAFT-0978.html
# ACF-2023-0011-DRAFT-0979.html
# ACF-2023-0011-DRAFT-0980.html
# ACF-2023-0011-DRAFT-0981.html
# ACF-2023-0011-DRAFT-0982.html
# ACF-2023-0011-DRAFT-0983.html
# ACF-2023-0011-DRAFT-0984.html
# ACF-2023-0011-DRAFT-0985.html
# ACF-2023-0011-DRAFT-0986.html
# ACF-2023-0011-DRAFT-0987.html
# ACF-2023-0011-DRAFT-0988.html
# ACF-2023-0011-DRAFT-0989.html
# ACF-2023-0011-DRAFT-0990.html
# ACF-2023-0011-DRAFT-0991.html
# ACF-2023-0011-DRAFT-0992.html
# ACF-2023-0011-DRAFT-0993.html
# ACF-2023-0011-DRAFT-0994.html
# ACF-2023-0011-DRAFT-0995.html
# ACF-2023-0011-DRAFT-0996.html
# ACF-2023-0011-DRAFT-0997.html
# ACF-2023-0011-DRAFT-0998.html
# ACF-2023-0011-DRAFT-0999.html
# ACF-2023-0011-DRAFT-1000.html
# ACF-2023-0011-DRAFT-1001.html
# ACF-2023-0011-DRAFT-1002.html
# ACF-2023-0011-DRAFT-1003.html
# ACF-2023-0011-DRAFT-1004.html
# ACF-2023-0011-DRAFT-1005.html
# ACF-2023-0011-DRAFT-1006.html
# ACF-2023-0011-DRAFT-1007.html
# ACF-2023-0011-DRAFT-1008.html
# ACF-2023-0011-DRAFT-1009.html
# ACF-2023-0011-DRAFT-1010.html
# ACF-2023-0011-DRAFT-1011.html
# ACF-2023-0011-DRAFT-1012.html
# ACF-2023-0011-DRAFT-1013.html
# ACF-2023-0011-DRAFT-1014.html
# ACF-2023-0011-DRAFT-1015.html
# ACF-2023-0011-DRAFT-1016.html
# ACF-2023-0011-DRAFT-1017.html
# ACF-2023-0011-DRAFT-1018.html
# ACF-2023-0011-DRAFT-1019.html
# ACF-2023-0011-DRAFT-1020.html
# ACF-2023-0011-DRAFT-1021.html
# ACF-2023-0011-DRAFT-1022.html
# ACF-2023-0011-DRAFT-1023.html
# ACF-2023-0011-DRAFT-1024.html
# ACF-2023-0011-DRAFT-1025.html
# ACF-2023-0011-DRAFT-1026.html
# ACF-2023-0011-DRAFT-1027.html
# ACF-2023-0011-DRAFT-1028.html
# ACF-2023-0011-DRAFT-1029.html
# ACF-2023-0011-DRAFT-1030.html
# ACF-2023-0011-DRAFT-1031.html
# ACF-2023-0011-DRAFT-1032.html
# ACF-2023-0011-DRAFT-1033.html
# ACF-2023-0011-DRAFT-1034.html
# ACF-2023-0011-DRAFT-1035.html
# ACF-2023-0011-DRAFT-1036.html
# ACF-2023-0011-DRAFT-1037.html
# ACF-2023-0011-DRAFT-1038.html
# ACF-2023-0011-DRAFT-1039.html
# ACF-2023-0011-DRAFT-1040.html
# ACF-2023-0011-DRAFT-1041.html
# ACF-2023-0011-DRAFT-1042.html
# ACF-2023-0011-DRAFT-1043.html
# ACF-2023-0011-DRAFT-1044.html
# ACF-2023-0011-DRAFT-1045.html
# ACF-2023-0011-DRAFT-1046.html
# ACF-2023-0011-DRAFT-1047.html
# ACF-2023-0011-DRAFT-1048.html
# ACF-2023-0011-DRAFT-1049.html
# ACF-2023-0011-DRAFT-1050.html
# ACF-2023-0011-DRAFT-1051.html
# ACF-2023-0011-DRAFT-1052.html
# ACF-2023-0011-DRAFT-1053.html
# ACF-2023-0011-DRAFT-1054.html
# ACF-2023-0011-DRAFT-1055.html
# ACF-2023-0011-DRAFT-1056.html
# ACF-2023-0011-DRAFT-1057.html
# ACF-2023-0011-DRAFT-1058.html
# ACF-2023-0011-DRAFT-1059.html
# ACF-2023-0011-DRAFT-1060.html
# ACF-2023-0011-DRAFT-1061.html
# ACF-2023-0011-DRAFT-1062.html
# ACF-2023-0011-DRAFT-1063.html
# ACF-2023-0011-DRAFT-1064.html
# ACF-2023-0011-DRAFT-1065.html
# ACF-2023-0011-DRAFT-1066.html
# ACF-2023-0011-DRAFT-1067.html
# ACF-2023-0011-DRAFT-1068.html
# ACF-2023-0011-DRAFT-1069.html
# ACF-2023-0011-DRAFT-1070.html
# ACF-2023-0011-DRAFT-1071.html
# ACF-2023-0011-DRAFT-1072.html
# ACF-2023-0011-DRAFT-1073.html
# ACF-2023-0011-DRAFT-1074.html
# ACF-2023-0011-DRAFT-1075.html
# ACF-2023-0011-DRAFT-1076.html
# ACF-2023-0011-DRAFT-1077.html
# ACF-2023-0011-DRAFT-1078.html
# ACF-2023-0011-DRAFT-1079.html
# ACF-2023-0011-DRAFT-1080.html
# ACF-2023-0011-DRAFT-1081.html
# ACF-2023-0011-DRAFT-1082.html
# ACF-2023-0011-DRAFT-1083.html
# ACF-2023-0011-DRAFT-1084.html
# ACF-2023-0011-DRAFT-1085.html
# ACF-2023-0011-DRAFT-1086.html
# ACF-2023-0011-DRAFT-1087.html
# ACF-2023-0011-DRAFT-1088.html
# ACF-2023-0011-DRAFT-1089.html
# ACF-2023-0011-DRAFT-1090.html
# ACF-2023-0011-DRAFT-1091.html
# ACF-2023-0011-DRAFT-1092.html
# ACF-2023-0011-DRAFT-1093.html
# ACF-2023-0011-DRAFT-1094.html
# ACF-2023-0011-DRAFT-1095.html
# ACF-2023-0011-DRAFT-1096.html
# ACF-2023-0011-DRAFT-1097.html
# ACF-2023-0011-DRAFT-1098.html
# ACF-2023-0011-DRAFT-1099.html
# ACF-2023-0011-DRAFT-1100.html
# ACF-2023-0011-DRAFT-1101.html
# ACF-2023-0011-DRAFT-1102.html
# ACF-2023-0011-DRAFT-1103.html
# ACF-2023-0011-DRAFT-1104.html
# ACF-2023-0011-DRAFT-1105.html
# ACF-2023-0011-DRAFT-1106.html
# ACF-2023-0011-DRAFT-1107.html
# ACF-2023-0011-DRAFT-1108.html
# ACF-2023-0011-DRAFT-1109.html
# ACF-2023-0011-DRAFT-1110.html
# ACF-2023-0011-DRAFT-1111.html
# ACF-2023-0011-DRAFT-1112.html
# ACF-2023-0011-DRAFT-1113.html
# ACF-2023-0011-DRAFT-1114.html
# ACF-2023-0011-DRAFT-1115.html
# ACF-2023-0011-DRAFT-1116.html
# ACF-2023-0011-DRAFT-1117.html
# ACF-2023-0011-DRAFT-1118.html
# ACF-2023-0011-DRAFT-1119.html
# ACF-2023-0011-DRAFT-1120.html
# ACF-2023-0011-DRAFT-1121.html
# ACF-2023-0011-DRAFT-1122.html
# ACF-2023-0011-DRAFT-1123.html
# ACF-2023-0011-DRAFT-1124.html
# ACF-2023-0011-DRAFT-1125.html
# ACF-2023-0011-DRAFT-1126.html
# ACF-2023-0011-DRAFT-1127.html
# ACF-2023-0011-DRAFT-1128.html
# ACF-2023-0011-DRAFT-1129.html
# ACF-2023-0011-DRAFT-1130.html
# ACF-2023-0011-DRAFT-1131.html
# ACF-2023-0011-DRAFT-1132.html
# ACF-2023-0011-DRAFT-1133.html
# ACF-2023-0011-DRAFT-1134.html
# ACF-2023-0011-DRAFT-1135.html
# ACF-2023-0011-DRAFT-1136.html
# ACF-2023-0011-DRAFT-1137.html
# ACF-2023-0011-DRAFT-1138.html
# ACF-2023-0011-DRAFT-1139.html
# ACF-2023-0011-DRAFT-1140.html
# ACF-2023-0011-DRAFT-1141.html
# ACF-2023-0011-DRAFT-1142.html
# ACF-2023-0011-DRAFT-1143.html
# ACF-2023-0011-DRAFT-1144.html
# ACF-2023-0011-DRAFT-1145.html
# ACF-2023-0011-DRAFT-1146.html
# ACF-2023-0011-DRAFT-1147.html
# ACF-2023-0011-DRAFT-1148.html
# ACF-2023-0011-DRAFT-1149.html
# ACF-2023-0011-DRAFT-1150.html
# ACF-2023-0011-DRAFT-1151.html
# ACF-2023-0011-DRAFT-1152.html
# ACF-2023-0011-DRAFT-1153.html
# ACF-2023-0011-DRAFT-1154.html
# ACF-2023-0011-DRAFT-1155.html
# ACF-2023-0011-DRAFT-1156.html
# ACF-2023-0011-DRAFT-1157.html
# ACF-2023-0011-DRAFT-1158.html
# ACF-2023-0011-DRAFT-1159.html
# ACF-2023-0011-DRAFT-1160.html
# ACF-2023-0011-DRAFT-1161.html
# ACF-2023-0011-DRAFT-1162.html
# ACF-2023-0011-DRAFT-1163.html
# ACF-2023-0011-DRAFT-1164.html
# ACF-2023-0011-DRAFT-1165.html
# ACF-2023-0011-DRAFT-1166.html
# ACF-2023-0011-DRAFT-1167.html
# ACF-2023-0011-DRAFT-1168.html
# ACF-2023-0011-DRAFT-1169.html
# ACF-2023-0011-DRAFT-1170.html
# ACF-2023-0011-DRAFT-1171.html
# ACF-2023-0011-DRAFT-1172.html
# ACF-2023-0011-DRAFT-1173.html
# ACF-2023-0011-DRAFT-1174.html
# ACF-2023-0011-DRAFT-1175.html
# ACF-2023-0011-DRAFT-1176.html
# ACF-2023-0011-DRAFT-1177.html
# ACF-2023-0011-DRAFT-1178.html
# ACF-2023-0011-DRAFT-1179.html
# ACF-2023-0011-DRAFT-1180.html
# ACF-2023-0011-DRAFT-1181.html
# ACF-2023-0011-DRAFT-1182.html
# ACF-2023-0011-DRAFT-1183.html
# ACF-2023-0011-DRAFT-1184.html
# ACF-2023-0011-DRAFT-1185.html
# ACF-2023-0011-DRAFT-1186.html
# ACF-2023-0011-DRAFT-1187.html
# ACF-2023-0011-DRAFT-1188.html
# ACF-2023-0011-DRAFT-1189.html
# ACF-2023-0011-DRAFT-1190.html
# ACF-2023-0011-DRAFT-1191.html
# ACF-2023-0011-DRAFT-1192.html
# ACF-2023-0011-DRAFT-1193.html
# ACF-2023-0011-DRAFT-1194.html
# ACF-2023-0011-DRAFT-1195.html
# ACF-2023-0011-DRAFT-1196.html
# ACF-2023-0011-DRAFT-1197.html
# ACF-2023-0011-DRAFT-1198.html
# ACF-2023-0011-DRAFT-1199.html
# ACF-2023-0011-DRAFT-1200.html
# ACF-2023-0011-DRAFT-1201.html
# ACF-2023-0011-DRAFT-1202.html
# ACF-2023-0011-DRAFT-1203.html
# ACF-2023-0011-DRAFT-1204.html
# ACF-2023-0011-DRAFT-1205.html
# ACF-2023-0011-DRAFT-1206.html
# ACF-2023-0011-DRAFT-1207.html
# ACF-2023-0011-DRAFT-1208.html
# ACF-2023-0011-DRAFT-1209.html
# ACF-2023-0011-DRAFT-1210.html
# ACF-2023-0011-DRAFT-1211.html
# ACF-2023-0011-DRAFT-1212.html
# ACF-2023-0011-DRAFT-1213.html
# ACF-2023-0011-DRAFT-1214.html
# ACF-2023-0011-DRAFT-1215.html
# ACF-2023-0011-DRAFT-1216.html
# ACF-2023-0011-DRAFT-1217.html
# ACF-2023-0011-DRAFT-1218.html
# ACF-2023-0011-DRAFT-1219.html
# ACF-2023-0011-DRAFT-1220.html
# ACF-2023-0011-DRAFT-1221.html
# ACF-2023-0011-DRAFT-1222.html
# ACF-2023-0011-DRAFT-1223.html
# ACF-2023-0011-DRAFT-1224.html
# ACF-2023-0011-DRAFT-1225.html
# ACF-2023-0011-DRAFT-1226.html
# ACF-2023-0011-DRAFT-1227.html
# ACF-2023-0011-DRAFT-1228.html
# ACF-2023-0011-DRAFT-1229.html
# ACF-2023-0011-DRAFT-1230.html
# ACF-2023-0011-DRAFT-1231.html
# ACF-2023-0011-DRAFT-1232.html
# ACF-2023-0011-DRAFT-1233.html
# ACF-2023-0011-DRAFT-1234.html
# ACF-2023-0011-DRAFT-1235.html
# ACF-2023-0011-DRAFT-1236.html
# ACF-2023-0011-DRAFT-1237.html
# ACF-2023-0011-DRAFT-1238.html
# ACF-2023-0011-DRAFT-1239.html
# ACF-2023-0011-DRAFT-1240.html
# ACF-2023-0011-DRAFT-1241.html
# ACF-2023-0011-DRAFT-1242.html
# ACF-2023-0011-DRAFT-1243.html
# ACF-2023-0011-DRAFT-1244.html
# ACF-2023-0011-DRAFT-1245.html
# ACF-2023-0011-DRAFT-1246.html
# ACF-2023-0011-DRAFT-1247.html
# ACF-2023-0011-DRAFT-1248.html
# ACF-2023-0011-DRAFT-1249.html
# ACF-2023-0011-DRAFT-1250.html
# ACF-2023-0011-DRAFT-1251.html
# ACF-2023-0011-DRAFT-1252.html
# ACF-2023-0011-DRAFT-1253.html
# ACF-2023-0011-DRAFT-1254.html
# ACF-2023-0011-DRAFT-1255.html
# ACF-2023-0011-DRAFT-1256.html
# ACF-2023-0011-DRAFT-1257.html
# ACF-2023-0011-DRAFT-1258.html
# ACF-2023-0011-DRAFT-1259.html
# ACF-2023-0011-DRAFT-1260.html
# ACF-2023-0011-DRAFT-1261.html
# ACF-2023-0011-DRAFT-1262.html
# ACF-2023-0011-DRAFT-1263.html
# ACF-2023-0011-DRAFT-1264.html
# ACF-2023-0011-DRAFT-1265.html
# ACF-2023-0011-DRAFT-1266.html
# ACF-2023-0011-DRAFT-1267.html
# ACF-2023-0011-DRAFT-1268.html
# ACF-2023-0011-DRAFT-1269.html
# ACF-2023-0011-DRAFT-1270.html
# ACF-2023-0011-DRAFT-1271.html
# ACF-2023-0011-DRAFT-1272.html
# ACF-2023-0011-DRAFT-1273.html
# ACF-2023-0011-DRAFT-1274.html
# ACF-2023-0011-DRAFT-1275.html
# ACF-2023-0011-DRAFT-1276.html
# ACF-2023-0011-DRAFT-1277.html
# ACF-2023-0011-DRAFT-1278.html
# ACF-2023-0011-DRAFT-1279.html
# ACF-2023-0011-DRAFT-1280.html
# ACF-2023-0011-DRAFT-1281.html
# ACF-2023-0011-DRAFT-1282.html
# ACF-2023-0011-DRAFT-1283.html
# ACF-2023-0011-DRAFT-1284.html
# ACF-2023-0011-DRAFT-1285.html
# ACF-2023-0011-DRAFT-1286.html
# ACF-2023-0011-DRAFT-1287.html
# ACF-2023-0011-DRAFT-1288.html
# ACF-2023-0011-DRAFT-1289.html
# ACF-2023-0011-DRAFT-1290.html
# ACF-2023-0011-DRAFT-1291.html
# ACF-2023-0011-DRAFT-1292.html
# ACF-2023-0011-DRAFT-1293.html
# ACF-2023-0011-DRAFT-1294.html
# ACF-2023-0011-DRAFT-1295.html
# ACF-2023-0011-DRAFT-1296.html
# ACF-2023-0011-DRAFT-1297.html
# ACF-2023-0011-DRAFT-1298.html
# ACF-2023-0011-DRAFT-1299.html
# ACF-2023-0011-DRAFT-1300.html
# ACF-2023-0011-DRAFT-1301.html
# ACF-2023-0011-DRAFT-1302.html
# ACF-2023-0011-DRAFT-1303.html
# ACF-2023-0011-DRAFT-1304.html
# ACF-2023-0011-DRAFT-1305.html
# ACF-2023-0011-DRAFT-1306.html
# ACF-2023-0011-DRAFT-1307.html
# ACF-2023-0011-DRAFT-1308.html
#               As of                                            Comment  \
# 0  January 20, 2024  While I am in support of increased wages and b...
# 1  January 20, 2024  -First while I commend the need for HS staff t...
# 2  January 20, 2024  Head Start teachers should be salaried. We wor...
# 3  January 20, 2024  We want to get PAID!!!! We work hard for the l...
# 4  January 20, 2024  Are you going to address increased funding to ...
#
#             Received  Status             Posted  Tracking No.   \
# 0  November 21, 2023  Posted  November 28, 2023  lp8-i19p-nqbk
# 1  November 22, 2023  Posted  November 28, 2023  lpa-9kok-o7f7
# 2  November 23, 2023  Posted  November 28, 2023  lpb-j5uy-g8uv
# 3  November 21, 2023  Posted  November 28, 2023  lp8-s4af-cz42
# 4  November 22, 2023  Posted  November 28, 2023  lp9-wsu0-lx3k
#
#        Comments Due Submission Type         Docket          Comment On  ...  \
# 0  January 19, 2024             API  ACF-2023-0011  ACF-2023-0011-0001  ...
# 1  January 19, 2024             Web  ACF-2023-0011  ACF-2023-0011-0001  ...
# 2  January 19, 2024             API  ACF-2023-0011  ACF-2023-0011-0001  ...
# 3  January 19, 2024             Web  ACF-2023-0011  ACF-2023-0011-0001  ...
# 4  January 19, 2024             API  ACF-2023-0011  ACF-2023-0011-0001  ...
#
#          Phone Organization attachment_name  attachment_text  \
# 0          NaN          NaN             NaN              NaN
# 1          NaN          NaN             NaN              NaN
# 2          NaN          NaN             NaN              NaN
# 3   8475325635          NaN             NaN              NaN
# 4          NaN          NaN             NaN              NaN
#
#    attachment_has_tables attachment_error  \
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
#
#                                        Comment_clean attachment_text_clean  \
# 0  While I am in support of increased wages and b...
# 1  -First while I commend the need for HS staff t...
# 2  Head Start teachers should be salaried. We wor...
# 3  We want to get PAID!!!! We work hard for the l...
# 4  Are you going to address increased funding to ...
#
#   head_start_commenter congress_commenter
# 0                  NaN              False
# 1                  NaN              False
# 2                  NaN              False
# 3                  NaN              False
# 4                  NaN              False
#
# [5 rows x 28 columns]

# %%
dff.loc[~dff['Government Agency'].isna(), 'Government Agency'] = dff.loc[~dff['Government Agency'].isna(), 'Government Agency'].apply(lambda x: x[1:])

# %%
dff.loc[dff['Government Agency'].isin(["Senate HELP Committee, Chair Sanders",'U.S. House Committee on Education and the Workforce','Office of Congressman Adam B. Schiff']),'congress_commenter'] = True

# %%
dff[(dff['head_start_commenter']==1) | (dff['congress_commenter']==1)].to_excel('important_commenter.xlsx')

# %%
# single out importanta commenter and put html and attachment into a folder
import pandas as pd
import shutil
import os
import glob
dff1 = dff[(dff['head_start_commenter']==1) | (dff['congress_commenter']==1)]
file_source = 'C:\\Users\\HaoLuo\\ACF-2023-0011\\ACF-2023-0011'
file_destination = 'C:\\Users\\HaoLuo\\ACF-2023-0011\\important_commenter\\'
shutil.copy2('important_commenter.xlsx', file_destination)

os.chdir(file_source)
directory = glob.glob('*')
htm = [x+'.html' for x in dff1['Document']]

for file in directory:
    if file in dff1['attachment_name'].tolist():
        shutil.copy2(file_source+'\\'+file, file_destination)
    if file in htm:
        shutil.copy2(file_source+'\\'+file, file_destination)

# %%
dff['Document']=np.where((dff['attachment_name'].apply(lambda x: str(x).split('.')[0])!='nan'),
dff['attachment_name'].apply(lambda x: str(x).split('.')[0]),
dff['Document'])

# %%
dff.to_pickle('2023_scrape.pkl')
print('Total Time consumed: ', time.time()-st)
# Out:
# Total Time consumed:  78.34600853919983
